# %% [markdown]
# # Sentiment analysis using pre-trained language models

# %% [markdown]
# ## Download Hugging face lib
#
# https://huggingface.co/docs/transformers/v4.15.0/installation

# %%
import json
# !conda install -c huggingface transformers
# !pip install torch 
# !pip install chardet
# Out:
# 'conda' is not recognized as an internal or external command,
# operable program or batch file.
# Requirement already satisfied: torch in c:\users\user\desktop\ml for text\venv\lib\site-packages (1.13.1)
# Requirement already satisfied: typing-extensions in c:\users\user\desktop\ml for text\venv\lib\site-packages (from torch) (4.5.0)
# Requirement already satisfied: chardet in c:\users\user\desktop\ml for text\venv\lib\site-packages (5.1.0)

# %%
from transformers import pipeline

classifier = pipeline("sentiment-analysis")
classifier("I am impressed how long this ink last and how fast the seller sent it to me. Not a hitch at all, fantastic.")
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# [{'label': 'POSITIVE', 'score': 0.9994031190872192}]

# %%
import json
import string
import re
import numpy as np
with open('reviews.json') as f:
    reviews = json.load(f)
# print(json.dumps(reviews, indent=2))

sentiment_dict = dict()
for brand in reviews:
    brand_dict = dict()
    for category in reviews[brand]:
        category_dict = dict()
        for product in reviews[brand][category]:
            sentiment_list = []
            for review in reviews[brand][category][product]:
                if len(review) > 0:
                    # Remove punctuation
                    review_p = "".join(char for char in review if char not in string.punctuation)
                    # Only get alphanumeric characters
                    review_sub = re.sub(r'[^a-zA-z0-9 ]', "", review_p)
                    # Replace all whitespace with space
                    review_sub = re.sub(r"[\s]", " ", review_sub)
                    # Replace multiple spaces with one space
                    review_sub = re.sub("  ", " ", review_sub)
                    # print(review_sub)
                    try:
                        score = classifier(review_sub)[0]['score']
                        print(score)
                        sentiment_list.append(score)
                    except Exception as e:
                        print(e)
            category_dict[product] = np.mean(sentiment_list)
        brand_dict[category] = category_dict
    sentiment_dict[brand] = brand_dict

print(sentiment_dict)
with open('reviews_sentiment.json', 'w') as f:
    json.dump(sentiment_dict, f, indent=2)
# Out:
# 0.6098417043685913
# 0.7794283628463745
# 0.9988512992858887
# The size of tensor a (836) must match the size of tensor b (512) at non-singleton dimension 1
# The size of tensor a (614) must match the size of tensor b (512) at non-singleton dimension 1
# 0.7103496193885803
# 0.9996998310089111
# 0.9819761514663696
# 0.9946335554122925
# 0.7253584861755371
# 0.6098417043685913
# 0.7794283628463745
# 0.9988512992858887
# The size of tensor a (836) must match the size of tensor b (512) at non-singleton dimension 1
# The size of tensor a (614) must match the size of tensor b (512) at non-singleton dimension 1
# 0.7103496193885803
# 0.9996998310089111
# 0.9819761514663696
# 0.9946335554122925
# 0.7253584861755371
# 0.5543690919876099
# 0.9967535138130188
# The size of tensor a (609) must match the size of tensor b (512) at non-singleton dimension 1
# The size of tensor a (545) must match the size of tensor b (512) at non-singleton dimension 1
# 0.9907482266426086
# 0.9997746348381042
# 0.9559769630432129
# 0.9977536797523499
# 0.9993075132369995
# 0.9911980032920837
# 0.9967889785766602
# 0.9989213943481445
# 0.9998218417167664
# 0.9858449697494507
# 0.9998416900634766
# 0.9845287203788757
# 0.9979664087295532
# 0.9984990358352661
# 0.9995598196983337
# 0.9820336699485779
# 0.9359863996505737
# 0.996119499206543
# 0.9924677014350891
# 0.9993403553962708
# 0.9230203032493591
# 0.7102155685424805
# 0.9739834666252136
# 0.9215952754020691
# 0.9604440927505493
# 0.8030222654342651
# 0.9367798566818237
# 0.9169597029685974
# 0.9991656541824341
# 0.9976370334625244
# 0.9998051524162292
# 0.9972283244132996
# 0.9717797636985779
# 0.9995235204696655
# 0.9835241436958313
must match the size of tensor b (512) at non-singleton dimension 1
# 0.9747563600540161
# 0.8189457058906555
# 0.9646732807159424
# 0.9984127283096313
# 0.8334559202194214
# The size of tensor a (568) must match the size of tensor b (512) at non-singleton dimension 1
# The size of tensor a (613) must match the size of tensor b (512) at non-singleton dimension 1
# 0.9763982892036438
# The size of tensor a (638) must match the size of tensor b (512) at non-singleton dimension 1
# 0.7204408049583435
# 0.9026613831520081
# 0.9952785968780518
# The size of tensor a (759) must match the size of tensor b (512) at non-singleton dimension 1
# The size of tensor a (1148) must match the size of tensor b (512) at non-singleton dimension 1
# 0.8451863527297974
# The size of tensor a (568) must match the size of tensor b (512) at non-singleton dimension 1
# The size of tensor a (613) must match the size of tensor b (512) at non-singleton dimension 1
# 0.9763982892036438
# The size of tensor a (638) must match the size of tensor b (512) at non-singleton dimension 1
# 0.7204408049583435
# 0.9026613831520081
# 0.9952785968780518
# The size of tensor a (759) must match the size of tensor b (512) at non-singleton dimension 1
# The size of tensor a (1148) must match the size of tensor b (512) at non-singleton dimension 1
# 0.8451863527297974
# The size of tensor a (773) must match the size of tensor b (512) at non-singleton dimension 1
# 0.9977263808250427
# 0.9997015595436096
# 0.5826873779296875
# 0.9848061203956604
# 0.9922181367874146
# 0.5488483309745789
# 0.9965121150016785
# 0.9743589758872986
# The size of tensor a (682) must match the size of tensor b (512) at non-singleton dimension 1
# 0.9985330104827881
# 0.9994762539863586
# 0.99795001745224
# 0.9764482975006104
# 0.9916302561759949
# The size of tensor a (611) must match the size of tensor b (512) at non-singleton dimension 1
# 0.9985023736953735
# 0.999882698059082
# 0.9738922119140625
# 0.9997372031211853
# 0.9984176158905029
# 0.9872231483459473
# 0.9817319512367249
# 0.5122566819190979
# The size of tensor a (578) must match the size of tensor b (512) at non-singleton dimension 1
# 0.9965121150016785
# The size of tensor a (595) must match the size of tensor b (512) at non-singleton dimension 1
# 0.9994476437568665
# 0.9992105960845947
# 0.9754517674446106
# 0.9876618385314941
# 0.9974560141563416
# The size of tensor a (762) must match the size of tensor b (512) at non-singleton dimension 1
# 0.9860671162605286
# 0.9347178936004639
# 0.9798041582107544
# 0.9993767142295837
# 0.999451220035553
# 0.9963259100914001
# 0.9908539056777954
# 0.9944774508476257
# 0.8009310364723206
# 0.9966034889221191
# 0.9860671162605286
# 0.9347178936004639
# 0.9798041582107544
# 0.9993767142295837
# 0.999451220035553
# 0.9963259100914001
# 0.9908539056777954
# 0.9944774508476257
# 0.8009310364723206
# 0.9966034889221191
# 0.999875545501709
# 0.6078047156333923
# 0.9986149072647095
# 0.9859711527824402
# 0.9824604392051697
# 0.9998595714569092
# 0.9998611211776733
# 0.9992591738700867
# 0.9937805533409119
# 0.9466776251792908
# 0.9978135824203491
# 0.9879406690597534
# 0.9996111989021301
# 0.9942507743835449
# 0.9877217411994934
# 0.9809534549713135
# 0.9544996619224548
# 0.9925140738487244
# 0.9988448619842529
# 0.9969879984855652
# 0.9979574680328369
# 0.9998667240142822
# 0.9935985803604126
# 0.8621107339859009
# 0.9993125200271606
# 0.9933602213859558
# 0.9978263974189758
# 0.9778754711151123
# 0.9403205513954163
# 0.9981946349143982
# 0.9997835755348206
# The size of tensor a (1132) must match the size of tensor b (512) at non-singleton dimension 1
# The size of tensor a (1434) must match the size of tensor b (512) at non-singleton dimension 1
# 0.9667708873748779
# 0.9965121150016785
# 0.9975010752677917
# 0.9463678002357483
# 0.997557520866394
# 0.8117815256118774
# 0.994758665561676
# 0.9978410005569458
# The size of tensor a (797) must match the size of tensor b (512) at non-singleton dimension 1
# 0.9994775652885437
# 0.9010016322135925
# The size of tensor a (1132) must match the size of tensor b (512) at non-singleton dimension 1
# The size of tensor a (1434) must match the size of tensor b (512) at non-singleton dimension 1
# 0.9667708873748779
# 0.9965121150016785
# 0.9975010752677917
# 0.9463678002357483
# 0.997557520866394
# 0.8117815256118774
# 0.994758665561676
# 0.9978410005569458
# The size of tensor a (797) must match the size of tensor b (512) at non-singleton dimension 1
# 0.
# The size of tensor a (548) must match the size of tensor b (512) at non-singleton dimension 1
# 0.56421959400177
# 0.9987099170684814
# 0.99349045753479
# 0.9885157346725464
# 0.9876556992530823
# 0.9978339076042175
# 0.8361340165138245
# 0.9877306818962097
# 0.9958439469337463
# The size of tensor a (548) must match the size of tensor b (512) at non-singleton dimension 1
# 0.56421959400177
# 0.9987099170684814
# 0.99349045753479
# 0.996292233467102
# 0.9978583455085754
# 0.9965121150016785
# 0.924925684928894
# 0.9998860359191895
# 0.9996345043182373
# 0.9763792157173157
# 0.865226149559021
# 0.9965121150016785
# 0.9981173276901245
# 0.9997724890708923
# 0.9998680353164673
# 0.9945101737976074
# 0.9988719820976257
# 0.9872231483459473
# 0.9920583367347717
# 0.9977020621299744
# 0.9990367889404297
# 0.9930572509765625
# 0.9963316321372986
# 0.9830108880996704
# 0.966282308101654
# 0.8447543382644653
# {'Razer': {'Mouse': {'Razer Orochi V2 Mobile Wireless Gaming Mouse: Ultra Lightweight - 2 Wireless Modes - Up to 950hrs Battery Life - Mechanical Mouse Switches - 5G Advanced 18K DPI Optical Sensor - White': 0.9146854796192863, 'Razer DeathAdder Essential Gaming Mouse: 6400 DPI Optical Sensor - 5 Programmable Buttons - Mechanical Switches - Rubber Side Grips - Classic Black': 0.9696124256873617, 'Razer Basilisk V3 Customizable Ergonomic Gaming Mouse: Fastest Gaming Mouse Switch - Chroma RGB Lighting - 26K DPI Optical Sensor - 11 Programmable Buttons - HyperScroll Tilt Wheel - Classic Black': 0.9676472313550054, 'Razer Mamba Elite Wired Gaming Mouse: 16,000 DPI Optical Sensor - Chroma RGB Lighting - 9 Programmable Buttons - Mechanical Switches': 0.9837815038701321, 'Razer Basilisk Ultimate HyperSpeed Wireless Gaming Mouse: Fastest Gaming Mouse Switch, 20K DPI Optical Sensor, Chroma RGB Lighting, 11 Programmable Buttons, 100 Hr Battery, Classic Black': 0.9277895012417355}, 'Keyboard': {'Razer BlackWidow V3 Mechanical Gaming Keyboard: Yellow Mechanical Switches - Linear & Silent - Chroma RGB Lighting - Compact Form Factor - Programmable Macro Functionality, Classic Black': 0.9710338723425772, 'Razer Ornata Chroma Gaming Keyboard: Hybrid Mechanical Key Switches - Customizable Chroma RGB Lighting - Individually Backlit Keys - Detachable Plush Wrist Rest - Programmable Macro Functionality': 0.9759486470467005, 'Razer Ornata V3 X Gaming Keyboard: Low-Profile Keys - Silent Membrane Switches - Spill Resistant - Chroma RGB Lighting - Ergonomic Wrist Rest - Classic Black': 0.9644474630453148, 'Razer Huntsman Mini 60% Gaming Keyboard: Fast Keyboard Switches - Linear Optical Switches - Chroma RGB Lighting - PBT Keycaps - Onboard Memory - Classic Black': 0.9483593070507049, 'Razer Huntsman V2 Optical Gaming Keyboard: Fastest Linear Optical Switches Gen-2 w/Sound Dampeners & 8000Hz Polling Rate - Doubleshot PBT Keycaps - Dedicated Media Keys & Dial - Ergonomic Wrist Rest': 0.9561973432215248}}}
